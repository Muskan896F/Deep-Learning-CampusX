# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ushape.csv", header=None)
df.head()
# Out:
#           0         1    2
# 0  0.031595  0.986988  0.0
# 1  2.115098 -0.046244  1.0
# 2  0.882490 -0.075756  0.0
# 3 -0.055144 -0.037332  1.0
# 4  0.829545 -0.539321  1.0

# %%
df.columns
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
df[0]
# Out:
# 0     0.031595
# 1     2.115098
# 2     0.882490
# 3    -0.055144
# 4     0.829545
#         ...
# 95    1.699453
# 96    0.218623
# 97    0.952914
# 98   -1.318500
# 99   -1.296818
# Name: 0, Length: 100, dtype: float64

# %%
plt.scatter(df[0],df[1],c=df[2])

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# c:\Users\HP\Deep-Learning-CampusX\campus\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
# ...

# %%
# Set parameters to 0
model.get_weights()
# Out:
# [array([[ 1.0653371 ,  0.96557295],
#         [-0.44117057, -0.5754053 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.39488053],
#         [-0.22055376]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.random.randn(*initial_weights[0].shape) * 0.5
initial_weights[1] = np.random.randn(*initial_weights[1].shape) * 0.5
initial_weights[2] = np.random.randn(*initial_weights[2].shape) * 0.5
initial_weights[3] = np.random.randn(*initial_weights[3].shape) * 0.5

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[-0.31087628, -0.03213892],
#         [ 1.0503527 ,  0.19640404]], dtype=float32),
#  array([-0.61305124,  1.1595497 ], dtype=float32),
#  array([[-0.4214868],
#         [-0.2509185]], dtype=float32),
#  array([0.66513246], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.5297 - loss: 0.6657 - val_accuracy: 0.5500 - val_loss: 0.6707
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4969 - loss: 0.6785 - val_accuracy: 0.5500 - val_loss: 0.6694
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5242 - loss: 0.6734 - val_accuracy: 0.5500 - val_loss: 0.6681
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5070 - loss: 0.6797 - val_accuracy: 0.6000 - val_loss: 0.6668
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5383 - loss: 0.6660 - val_accuracy: 0.6000 - val_loss: 0.6655
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5539 - loss: 0.6650 - val_accuracy: 0.6000 - val_loss: 0.6641
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5133 - loss: 0.6731 - val_accuracy: 0.6000 - val_loss: 0.6628
# Epoch 8/100
# ...

# %%
model.get_weights()
# Out:
# [array([[-0.0996202 , -0.3443337 ],
#         [ 1.33586   ,  0.49736848]], dtype=float32),
#  array([-0.3265919,  1.2131336], dtype=float32),
#  array([[-0.72545993],
#         [-0.45604625]], dtype=float32),
#  array([0.6118389], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# <Axes: >

# %%
print("The End")
# Out:
# The End
